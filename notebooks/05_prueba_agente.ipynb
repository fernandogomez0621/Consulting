# %% [markdown]
# # 05 - Prueba del Agente
#
# Notebook para probar el agente antes de integrarlo en Streamlit.

# %%
# Copiar agente.py al directorio de trabajo si no esta
# (subelo al mismo directorio de este notebook)

from agente import Agente

agente = Agente()
print('Agente inicializado.')

# %%
# Prueba 1: Saludo
respuesta = agente.consultar("Hola, que puedes hacer?")
print(respuesta)

# %%
# Prueba 2: EDA
respuesta = agente.consultar("Que encontraste en el analisis exploratorio?")
print(respuesta)

# %%
# Prueba 3: Correlaciones
respuesta = agente.consultar("Que relacion hay entre la materia prima Y y el Equipo 1?")
print(respuesta)

# %%
# Prueba 4: Mejor modelo
respuesta = agente.consultar("Cual es el mejor modelo y por que?")
print(respuesta)

# %%
# Prueba 5: Prophet
respuesta = agente.consultar("Como le fue a Prophet comparado con Lasso?")
print(respuesta)

# %%
# Prueba 6: Proyecciones
respuesta = agente.consultar("Cuanto costaria el Equipo 1 en enero 2024?")
print(respuesta)

# %%
# Prueba 7: COVID
respuesta = agente.consultar("Como impacto el COVID las relaciones entre variables?")
print(respuesta)

# %%
# Prueba 8: IA convencional vs Agente
respuesta = agente.consultar("Cual es la diferencia entre una IA convencional y un agente de IA?")
print(respuesta)

# %%
# Prueba 9: Memoria conversacional
respuesta = agente.consultar("Y los intervalos de confianza de esa proyeccion que me dijiste?")
print(respuesta)

# %%
# Prueba 10: Pregunta libre
respuesta = agente.consultar("Que features son mas importantes para predecir el Equipo 2?")
print(respuesta)
